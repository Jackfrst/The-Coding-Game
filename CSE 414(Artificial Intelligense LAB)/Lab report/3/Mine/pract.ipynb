# %%
from sklearn import datasets
iris = datasets.load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
import seaborn as sns

iris_d = sns.load_dataset('iris')
correlation = iris_d.corr()

# sns.heatmap(correlation,cmap='winter',annot=True)
# sns.boxplot(data=iris_d, orient="h", palette="Set2")
# sns.pairplot(correlation)
# sns.distplot(a=iris_d['petal_width'], bins=40, color='m')
# sns.countplot(x='species',data=iris_d, palette="OrRd")
# sns.violinplot(x='species', y='petal_length', data=iris_d, palette='YlGnBu')
# sns.clustermap(iris_d)
# sns.regplot(x='petal_width', y='petal_length', data=iris_d)
# sns.lmplot(x = 'sepal_width', y = 'sepal_length', data = iris_d, col = 'species', hue = 'species', palette = 'YlGnBu')
sns.jointplot(x="sepal_width", y="petal_length", data=iris_d, kind="kde", color="m")

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...
